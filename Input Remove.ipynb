# %%
from bs4 import BeautifulSoup
import re
import pandas as pd
import os
from datetime import date

# %%
HtmlFile = open(r'D:\1001 Partnership Kit\Partnership Kit (Supply Chain) Fix.html', 'r')
soup = BeautifulSoup(HtmlFile, 'lxml')

# %%
for div in soup.find_all("div", {'class':'input'}): 
    div.decompose()

# %%
for div in soup.find_all("div", {'class':'prompt output_prompt'}): 
    div.decompose()

# %%
nama_output = 'Supply Chain '+str(date.today())+'.html'
with open(nama_output, "w") as file:
    file.write(str(soup))
