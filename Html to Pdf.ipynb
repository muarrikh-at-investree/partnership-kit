# %%
from bs4 import BeautifulSoup
import re
import pandas as pd
import os
import pdfkit

# %%
HtmlFile = open(r'D:\1001 Partnership Kit\Partnership Kit (Supply Chain)5.html', 'r')
soup = BeautifulSoup(HtmlFile, 'lxml')

# %%
for div in soup.find_all("div", {'class':'input'}): 
    div.decompose()

# %%
for div in soup.find_all("div", {'class':'prompt output_prompt'}): 
    div.decompose()

# %%
options = {
    'page-height': '120in',
    'page-width': '9in',
    'margin-top': '0.75in',
    'margin-right': '0.75in',
    'margin-bottom': '0.75in',
    'margin-left': '0.75in',
    'encoding': "UTF-8",
    'custom-header' : [
        ('Accept-Encoding', 'gzip')
    ],
    'cookie': [
        ('cookie-name1', 'cookie-value1'),
        ('cookie-name2', 'cookie-value2'),
    ],
    'no-outline': None
}

config = pdfkit.configuration(wkhtmltopdf=r'C:\\Program Files\\wkhtmltopdf\\bin\\wkhtmltopdf.exe')

pdfkit.from_string(str(soup), 'Fix5.pdf', configuration=config, options=options)
# Out:
# Loading pages (1/6)
# ...
# Counting pages (2/6)
# Resolving links (4/6)
# Loading headers and footers (5/6)
# Printing pages (6/6)
# Done
# True
